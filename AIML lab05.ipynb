# %% [markdown]
# <a href="https://www.kaggle.com/code/abdulwasiaabdulwahid/lab05?scriptVersionId=299970440" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **Lab 05**

# %%
# Example 1 mean (average of nubmers)
import numpy 
speed = [99,86,67,66,111,86,103,87,94,78,77,85,86]
x = numpy.mean(speed)
print(x)
# Out:
# 86.53846153846153

# %%
# Example 2 median ( the between number)
import numpy
speed = [99,86,67,66,11,86,103,87,94,78,77,85,86]
x = numpy.median(speed)
print(x)
# Out:
# 86.0

# %%
# Example 3 Mode(most occur number)
import statistics
speed = [99,86,67,66,11,86,103,87,94,78,77,85,86]
x = statistics.mode(speed)
print(x)
# Out:
# 86

# %%
# Example 4 Std(Standard Deviation)
import numpy
speed = [86,87,88,86,87,85,86]
x = numpy.std(speed)
print (x)
# Out:
# 0.9035079029052513

# %%
# Example 5 var(Variance)
import numpy 
speed = [32,111,138,28,59,77,97]
x = numpy.var(speed)
print (x)
# Out:
# 1432.2448979591834

# %%
# Example 6 Percentiles
import numpy
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
x = numpy.percentile(ages, 90)
print ("90: ",x)
y = numpy.percentile(ages, 78)
print ("78: ",y)
# Out:
# 90:  61.0
# 78:  46.00000000000001

# %%
# Example 7 Data Distribution
import numpy 
x = numpy.random.uniform (0.0, 5.0, 250)
print (x)
# Out:
# [3.53174983 3.21837559 2.06012465 2.65054434 2.43638891 4.6176714
#  0.62849758 4.77941994 3.38623815 3.91436242 4.51256435 0.69574756
#  0.20618628 0.09494329 3.30690378 1.80166602 2.81122561 0.95756128
#  4.36006016 3.37398653 4.14545718 0.16307185 0.47058067 1.1211058
#  1.77678416 1.14945834 3.07655733 2.28201514 4.08279191 3.27885118
#  4.23911263 3.33061545 1.1317627  2.54477004 0.67674053 0.63248485
#  2.53679133 3.29498305 4.56625313 1.44109917 1.45787659 0.78783519
#  1.76731019 4.03558761 2.10165869 2.30153358 4.90674761 4.85913017
#  4.64887082 2.56564087 3.84594956 4.60973413 4.673957   4.37580896
#  4.44136017 1.3567925  1.28736986 3.02599871 2.19794486 2.32712126
#  0.17689713 2.13401084 2.52930913 4.4241084  4.83962856 4.36875976
#  3.14753028 2.57507513 4.93075189 4.37388296 3.89667248 3.00008802
#  3.61688011 0.30878561 4.82973954 1.12137193 2.51436339 3.30862011
#  4.60060956 1.72611647 2.3170034  4.60993046 0.38874496 0.87073119
#  0.15930122 0.37728218 2.00325239 0.69794338 0.0143541  2.58528556
#  4.23982665 2.95241732 2.71572943 0.6618101  3.55009705 2.40057682
#  2.71116064 0.53306923 3.61048212 1.2768086  3.4665425  2.05367208
#  3.63119175 1.46024851 4.08049068 4.39002077 3.35865284 1.62373898
#  2.77242974 0.09498976 4.40975799 2.33266494 4.51705819 4.92914655
#  0.68524281 4.28125291 4.06465896 4.85908415 2.5156836  1.36602569
#  2.90593023 2.79636579 3.79805815 4.49256903 2.70400133 3.90645015
#  0.58515725 4.88409461 3.45467496 0.36209602 0.3856466  3.8069426
#  3.03112798 1.1660601  4.11307606 2.98204746 0.44355705 2.11655085
#  1.36660278 1.96287628 2.38172485 4.75211844 2.16883382 1.26778488
#  1.82002859 1.82282683 4.30932811 1.73297477 4.49019599 4.8066021
#  4.41883261 4.94292409 0.26933076 0.33419414 2.83542651 0.17466289
#  1.37695789 3.96940759 2.83235721 4.63215499 0.07958229 0.16509519
#  4.51914388 3.96210522 4.22119279 0.7204561  0.4357309  1.08327356
#  0.68922182 2.36088537 2.82515075 4.31257936 3.5674157  0.33992902
#  0.54787493 4.28434183 1.37763426 0.44508411 0.44444363 4.84017067
#  3.88958723 0.81601045 3.14770692 3.63366394 2.1179533  1.31981881
#  3.96498674 4.24135037 0.72260894 1.30343512 0.5234691  1.5767896
#  3.07059763 0.66198674 4.1273491  2.18237285 4.66767396 2.69700831
#  0.41126159 0.35217662 2.96676771 4.68317458 1.00640411 3.84962291
#  0.68438496 3.60271385 3.88088301 1.11000784 4.0607036  2.7368342
#  1.85022738 0.28031418 1.49623333 2.5472421  1.40421963 0.24868096
#  1.93316349 1.36810612 2.29526725 4.95956542 2.29545736 2.69468435
#  2.3214324  4.43518153 1.57568366 1.08704116 2.12259893 0.39876474
#  3.14797835 4.00342712 0.4783159  3.89705794 2.41416472 3.26815893
#  3.97548525 2.98212457 0.9744549  1.22524915 3.17188647 0.3415716
#  0.88785064 0.82973189 2.95466816 4.02260173 2.03302504 2.54203144
#  3.67245969 2.73999438 1.36379464 3.49275496]

# %%
# Example 8 Histrogram
import numpy 
import matplotlib.pyplot as plt

x = numpy.random.uniform(1.0,5.0, 250)
plt.hist(x,15)
plt.show()

# %%
# Example 9  Normal Data Distribuiton
import numpy 
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0,1.0,100000)
plt.hist(x,100)
plt.show()

# %%
# Example 10
import matplotlib.pyplot as plt

x= [5,7,8,7,2,17,2,9,4,11,12,9,6]
y= [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.title("Car age vs speeed")
plt.grid(True)
plt.show()

# %% [markdown]
# Exercises

# %%
#Exercise  1
import numpy 
import statistics

dataset = [32, 6, 21, 10, 8, 11, 12, 36, 17, 16, 15, 18, 40, 24, 21, 23, 24, 24, 29, 16, 32, 31, 10, 30, 35, 32, 18, 39, 12, 20]
x = numpy.median(dataset)
print ("Media is : ", x)
y = numpy.mean(dataset)
print ("Mean is : ", y)
z = statistics.mode(dataset)
print ("Mode is : ",z)
# Out:
# Media is :  21.0
# Mean is :  22.066666666666666
# Mode is :  32

# %%
# Exercise 2
import statistics
dataset = [21, 19, 62, 21, 66, 28, 66, 48, 79, 59, 28, 62, 63, 63, 48, 66, 59, 66, 94, 79, 19, 94]

x = statistics.mode(dataset)
print ("Mode is : ", x)
# Out:
# Mode is :  66

# %%
#Exercise  3
import numpy 
import statistics

dataset = [23, 18, 24, 23, 31, 37, 28, 30, 25, 40, 35, 35, 27, 25]
x = numpy.median(dataset)
print ("Media is : ", x)
y = numpy.mean(dataset)
print ("Mean is : ", y)
z = statistics.mode(dataset)
print ("Mode is : ",z)
# Out:
# Media is :  27.5
# Mean is :  28.642857142857142
# Mode is :  23
