# %%
print('Hello World')
# Out:
# Hello World

# %%
'''Data Types in Python'''
# Out:
# 'Data Types in Python'

# %%
#INTEGER
number = 10
type(number)
#Determining the type of a number(varaible)
# Out:
# int

# %%
number=10.5
type(number)
# Out:
# float

# %%
text = 'HI Genius'
type(text)
# Out:
# str

# %%
#LIST IN PYTHON
my_friends = ['Farooq','Naveed','Toufiq','Sagar']
type(my_friends)
# Out:
# list

# %%
#Accessing element by its index:
my_friends = ['Farooq','Mohsin','Ali','Waqar']
my_friends[2]
# Out:
# 'Ali'

# %%
#Slicing the list means; we can choose the name among the list.
#FOr example we want: Name from 1-3, or names from 2-4.
my_friends=['Farooq','Naveed','Waqar','Huzaifa']
my_friends[0:3]
# Out:
# ['Farooq', 'Naveed', 'Waqar']

# %%
#Accessing first four or three names/elements from the list
my_friends=['Farooq','Manav', 'ALi','Junaid','Hammad']
my_friends[:2]
# Out:
# ['Farooq', 'Manav']

# %%
#leaving the first four accept remaining all.
# means fisrt four or three we eleminate and remaining we will get
my_friends=['Farooq','Manav', 'ALi','Junaid','Hammad']
my_friends[3:]
# Out:
# ['Junaid', 'Hammad']

# %%
#Getting the index of element or name
# it means we will find which is locate on which index
my_friends=['Farooq','Manav', 'ALi','Junaid','Hammad']
my_friends.index('Farooq'), my_friends.index('Junaid')
# Out:
# (0, 3)
